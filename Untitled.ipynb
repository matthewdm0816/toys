# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import SpectralClustering, KMeans
from sklearn.neighbors import NearestNeighbors
import os.path as osp
import torch
import pickle

# %%
a2v_path = osp.expanduser('~/data/bert-vqa/a2v_clip_top3k.pt')
embedded: np.ndarray = torch.load(a2v_path).numpy()
shift = 2
embedded = embedded[shift: shift+500]
lbl2idx_path = osp.expanduser('~/data/vqav2/lbl2idx_separate_top3k.pkl')
with open(lbl2idx_path, "rb") as f:
    lbl2idx, idx2lbl = pickle.load(f)
# embedded = embedded[2:]
print(embedded.shape, embedded)
# Out:
# (500, 1024) [[ 0.11322021  0.44458008 -0.0604248  ... -0.19433594  0.10357666
#    0.06130981]
#  [ 0.06982422  0.4333496  -0.13623047 ... -0.23803711  0.06518555
#    0.08843994]
#  [ 0.3803711   0.14538574 -0.18713379 ...  0.04244995 -0.4338379
#    0.4350586 ]
#  ...
#  [ 0.2109375  -0.20300293 -0.1685791  ...  0.29956055 -0.37573242
#    0.05245972]
#  [-0.2006836   0.29638672  0.1171875  ... -0.07568359 -0.10723877
#    0.43408203]
#  [-0.2680664   0.23242188  0.2836914  ... -0.18713379 -0.2130127
#    0.29638672]]

# %%
kmeans = KMeans(n_clusters=40)
kmeans.fit(embedded)
# Out:
# KMeans(n_clusters=40)

# %%
kmeans.cluster_centers_.shape
# Out:
# (40, 1024)

# %%
nn = NearestNeighbors(n_neighbors=1)
nn.fit(embedded)
# Out:
# NearestNeighbors(n_neighbors=1)

# %%
centroids = nn.kneighbors(kmeans.cluster_centers_, 2)[1][:,0]
centriods = centroids.sort()
print(centroids)
# Out:
# [  7  11  15  16  24  32  49  59  61  63  65  76  79  91  95 105 109 112
#  117 118 120 139 146 184 214 247 273 277 282 288 319 345 354 358 363 378
#  393 409 428 446]

# %%
centroids_lbl = [idx2lbl[int(centroid) + shift] for centroid in centroids]
print(centroids_lbl)
# Out:
# ['0', 'yellow', 'tennis', 'baseball', 'bathroom', 'skiing', 'surfboard', 'table', 'food', 'eating', 'banana', 'motorcycle', 'bear', 'walking', 'flowers', '11', 'car', 'cloudy', 'tree', 'kites', 'donut', 'cows', 'not sure', 'toothbrush', 'light', 'white and black', 'tomato', 'fire hydrant', 'picture', 'striped', 'wii controller', 'box', 'clothes', 'rock', 'lake', 'flying', '23', 'cup', 'fridge', 'steel']
